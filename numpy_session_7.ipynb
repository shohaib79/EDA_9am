# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num
#
# NameError: name 'num' is not defined

# %%
pwage=visa_df['prevailing_wage']

# %%
min(pwage)

# %%
np.min(pwage)

# %%
pwage.min()

# %% [markdown]
# **percentile-qualtile**

# %%
np.percentile(pwage,25)

# %%
np.quantile(pwage,0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.quantile(pwage,0.25)
#
# NameError: name 'pwage' is not defined

# %%
np.percentile(pwage,50)

# %%
np.percentile(pwage,75)

# %%
l=[]
for i in mum:
    pwage=visa_df[i]
    count=pwage.count()
    min=np.min(pwage)
    perc_25=np.percentile(pwage,25)
    mean=np.mean(pwage)
    median=np.median(pwage)
    perc_50=np.percentile(pwage,50)
    perc_75=np.percentile(pwage,75)
    max=np.max(pwage)
    label=['count','min','perc_25','mean,median','perc_50','perc_75','max']
    values=[count,min,perc_25,mean,median,perc_50,perc_75,max]
    pd.DataFrame(zip(label,values),columns=['Lable','Values'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 count=pwage.count()
#       2 min=np.min(pwage)
#       3 perc_25=np.percentile(pwage,25)
#
# NameError: name 'pwage' is not defined

# %% [markdown]
# **percentile**
#
# - 25p = 34015.48
#
# - there is 25 percentage of tot data has less value than wages 34015.48
# - what is the tot data
#       - 25380
# - 25 percentage of tot data
#      - 25480*25/100=6370
#
# - there is 6370 emp has wages less than 34015.48

# %% [markdown]
# **histogram**

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wwage_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 wage_data=visa_df['prevailing_wage']
#       2 plt.hist(wwage_data)
#
# NameError: name 'visa_df' is not defined

# %%
# for one interval we need two values
# 10 intervals so we need 11 values
# function returns 3 outputs
   # count of each interval
    # interval values
    # number of intervals

# %%
wage_data=visa_df['prevailing_wage']
f,values,n=plt.hist(wage_data)

# %%
n

# %%
values

# %%
f

# %%
q1 = np.percentile(wage,25)
q2 = np.percentile(wage,50)
q3 = np.percentile(wage,75)
iqr = q3-q1
lb = q1-1.5*iqr
ub = q3+1.5*iqr
con1 = wage<lb
con2 = wage>ub
cond = con1 | con2
len(visa[cond])

# %% [markdown]
# **winsoriaztion**
#
# - whatever the outliers less than lb fill with lb
#
# - whatever the otliers greater than ub fill the ub
#
# - in numpy we have method **clip**

# %%
g5
