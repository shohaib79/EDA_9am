# %% [markdown]
# **data analytics**

# %% [markdown]
# 1)pandas      :  DATA frame analysis
# 2)Numpy       : Numarical analysis
# 3)matplotlib  : Graphs and Plot
# 4)seaborn     : Plots
# 5)Bokhe       :   Plots
# 6)Plotly      :   Plots
#
# ======================== Machine learning =========================================================
#
# 7.stats           : for statistical models
# 8.SCIKIT-Learn(sklearn)     :  ML models
#
# ============================== Deep learning =========================================================
# 9.open cv       :  computer version
# 10.Pillow         :   Image operations
# 11.tensorflow     :  Neaural networks creation (developed by the google)
# kERAS      :  NN
# Pytorch      :  alternative package of tensorflow (facebook meta)
#
# ================================================ NLP  =======================================================
# NLKT       :  Natural Language Toolkit
# SpaCy       :  Alternative to NLKT
# wordCloud     : most frequent occured words
#
# ==================================================== Scrapping =============================================
# SqLite     : Data Base Creation
# Beautifil  soup
# Selenium
#
# ====================================================== Api Creations ================================================
# Flask
# FastApi
# Gradio
# Django
#
# ====================================================== Ui App Creation ===================================================
# Streamlit
#
# ========================================== Tranfer Learning Models(DL) ================================================
# Mobilenet
# Resnet
# VGGnet
# Inception
# Yolo    : ultralytics
#
# ========================================== Tranfer learning models(NLP) ===============================================
# Word2vec
# Glove
#
# ============================================ Huging Face Tranformers =====================================================
# BERT    : Bi directional Encoder representation of Transformers
#
# ============================================================== Allen NLP ========================================
# ALLEN NLP packages
#
# ========================================================== GENAI ===========================================================
# LangChain
# Google GeminiAi realted package
# OpenAi GPT related package
# Amazon BedRock related package
# Meta Llama related package
#
# ========================================== Iamge and video Generations =========================================================
# GAN models related packages
# SORA related packages
# nano banana
#
# =========================================================== Model deployment (MLOPS) ==============================================
# mlflow using databricks
# KuberFlow (GCP account)
#
# ================================================= cloud applications ===========================================================
# Azure ML related packages
# GCP VertexAI related package
# AWS Sagemaker related package
#
# ============================================================= small ========================================================
# time
# logging
# math
# random
# env
# os
